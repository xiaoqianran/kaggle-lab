# %% [markdown]
# # de-02 Supervised TinyUNet (P2)
# Synthetic easy RGB-D (color↔depth). Replace with NYU on Kaggle GPU.

# %%
import subprocess,sys
subprocess.check_call([sys.executable,'scripts/run_p2_train.py'])
