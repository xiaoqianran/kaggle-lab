# %% [markdown]
# # de-06 Claim reviews (P6)
# Open `papers/CLAIM_REVIEWS.md` and write one new arXiv card.

# %%
from pathlib import Path
p=Path('papers/CLAIM_REVIEWS.md')
print(p.read_text()[:1500])
