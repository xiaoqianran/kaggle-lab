# %% [markdown]
# # de-00 Metrics & Alignment (P0)
# Run unit tests and alignment experiment.

# %%
import subprocess, sys
from pathlib import Path
ROOT=Path('..').resolve() if False else Path('.').resolve()
# when opened from track root:
ROOT=Path('.').resolve()
import os
os.chdir(ROOT) if (ROOT/'scripts').exists() else os.chdir(ROOT.parent)
print('cwd', os.getcwd())
subprocess.check_call([sys.executable,'tests/test_metrics.py'])
subprocess.check_call([sys.executable,'scripts/run_p0_experiment.py'])
print('P0 done')
