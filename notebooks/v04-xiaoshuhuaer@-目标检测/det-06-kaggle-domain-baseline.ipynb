# %% [markdown]
# # P6 · 域偏移 baseline
#
# 学习向 notebook：调用 `scripts/` 可复现实验。六段闭环见 `LEARNING_ROADMAP.md`。

# %%
import runpy
from pathlib import Path
runpy.run_path(str(Path('scripts') / 'run_p6_domain.py'), run_name='__main__')
