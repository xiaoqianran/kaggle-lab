# %% [markdown]
# # P2 · 两阶段 lite + SOURCE_MAP
#
# 学习向 notebook：调用 `scripts/` 可复现实验。六段闭环见 `LEARNING_ROADMAP.md`。

# %%
import runpy
from pathlib import Path
runpy.run_path(str(Path('scripts') / 'run_p2_two_stage.py'), run_name='__main__')
