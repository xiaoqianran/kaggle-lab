# %% [markdown]
# # FS14 域偏移
#
# 地图：`FROM_SCRATCH.md`。运行后看 `results/` 图与 JSON。

# %%
import runpy
from pathlib import Path
runpy.run_path(str(Path('scripts')/'fs14_domain_viz.py'), run_name='__main__')
